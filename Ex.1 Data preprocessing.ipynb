# %%
import pandas as pd
from pandas import DataFrame
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.feature_selection import VarianceThreshold
data = {
    'name': ['Rex', 'Peter', 'Sam', 'Rita', 'Hilda'],
    'age': [1, 95, 22, 0, 60],
    'height': [20, 180, 160, 145, 125],
    'weight': [0, 100, 75, 55, 40],
    'bp': [80, 100, 65, 70, 40]
}
frame = DataFrame(data)
print("Original DataFrame:")
print(frame)
frame.to_csv('patient_data.csv', index=False)
df = pd.read_csv('patient_data.csv')
print("\nLoaded DataFrame:")
print(df)
df = df.replace(0, df.mean(numeric_only=True))
print("\nDataFrame after replacing zeros with column mean:")
print(df)
frame2 = df[['age', 'bp', 'height', 'weight']]
print("\nSelected Columns (frame2):")
print(frame2)
scaler = StandardScaler()
scaled = scaler.fit_transform(frame2)
print("\nStandard Scaled Data:")
print(scaled)
print("\nMean of scaled features:", scaled.mean(axis=0))
print("Standard deviation of scaled features:", scaled.std(axis=0))
frame3 = df[['age', 'bp', 'height', 'weight']]
min_max = MinMaxScaler()
scaled2 = min_max.fit_transform(frame3)
print("\nMin-Max Scaled Data:")
print(scaled2)
print("\nMean of MinMax scaled features:", scaled2.mean(axis=0))
print("Standard deviation of MinMax scaled features:", scaled2.std(axis=0))
sel = VarianceThreshold(threshold=(.5 * (1 - .9)))
useful_features1 = sel.fit_transform(scaled)
print("\nUseful feature values based on StandardScaler:")
print(useful_features1)
useful_features2 = sel.fit_transform(scaled2)
print("\nUseful feature values based on MinMaxScaler:")
print(useful_features2)
# Out:
# Original DataFrame:
#     name  age  height  weight   bp
# 0    Rex    1      20       0   80
# 1  Peter   95     180     100  100
# 2    Sam   22     160      75   65
# 3   Rita    0     145      55   70
# 4  Hilda   60     125      40   40
#
# Loaded DataFrame:
#     name  age  height  weight   bp
# 0    Rex    1      20       0   80
# 1  Peter   95     180     100  100
# 2    Sam   22     160      75   65
# 3   Rita    0     145      55   70
# 4  Hilda   60     125      40   40
#
# DataFrame after replacing zeros with column mean:
#     name   age  height  weight   bp
# 0    Rex   1.0      20      54   80
# 1  Peter  95.0     180     100  100
# 2    Sam  22.0     160      75   65
# 3   Rita  35.6     145      55   70
# 4  Hilda  60.0     125      40   40
#
# Selected Columns (frame2):
#     age   bp  height  weight
# 0   1.0   80      20      54
# 1  95.0  100     180     100
# 2  22.0   65     160      75
# 3  35.6   70     145      55
# 4  60.0   40     125      40
#
# Standard Scaled Data:
# [[-1.28721689  0.45927933 -1.89346102 -0.51832106]
#  [ 1.61303209  1.47990005  0.96459335  1.6893427 ]
#  [-0.63928892 -0.30618622  0.60733655  0.48952544]
#  [-0.21967843 -0.05103104  0.33939396 -0.47032837]
#  [ 0.53315215 -1.58196213 -0.01786284 -1.19021872]]
#
# Mean of scaled features: [ 2.22044605e-17 -4.44089210e-17  2.22044605e-17  8.88178420e-17]
# Standard deviation of scaled features: [1. 1. 1. 1.]
#
# Min-Max Scaled Data:
# [[0.         0.66666667 0.         0.23333333]
#  [1.         1.         1.         1.        ]
#  [0.22340426 0.41666667 0.875      0.58333333]
#  [0.36808511 0.5        0.78125    0.25      ]
#  [0.62765957 0.         0.65625    0.        ]]
#
# Mean of MinMax scaled features: [0.44382979 0.51666667 0.6625     0.41333333]
# Standard deviation of MinMax scaled features: [0.34479798 0.32659863 0.34988838 0.34727511]
#
# Useful feature values based on StandardScaler:
# [[-1.28721689  0.45927933 -1.89346102 -0.51832106]
#  [ 1.61303209  1.47990005  0.96459335  1.6893427 ]
#  [-0.63928892 -0.30618622  0.60733655  0.48952544]
#  [-0.21967843 -0.05103104  0.33939396 -0.47032837]
#  [ 0.53315215 -1.58196213 -0.01786284 -1.19021872]]
#
# Useful feature values based on MinMaxScaler:
# [[0.         0.66666667 0.         0.23333333]
#  [1.         1.         1.         1.        ]
#  [0.22340426 0.41666667 0.875      0.58333333]
#  [0.36808511 0.5        0.78125    0.25      ]
#  [0.62765957 0.         0.65625    0.        ]]
